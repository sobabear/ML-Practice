# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data=titanic, x='alive')
sns.histplot(data=titanic, x='age')
# Out:
# <Axes: xlabel='alive', ylabel='Count'>

# %%
sns.histplot(data=titanic, x='age', bins=10) # bins = 10개의 구간으로 나누어 히스토그램 그리기
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=titanic, x='age', hue='alive')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=titanic, x='age', hue='alive', multiple='stack')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(data=titanic, x='age', hue='alive', multiple='stack')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# ## 범주형 데이터

# %%
sns.barplot(data=titanic, x='class', y='fare')
# Out:
#   Cell In[22], line 1
#     sns.barplot(data=titanic, x='class', y='fare', data=titanic)
#                                                    ^
# SyntaxError: keyword argument repeated: data
